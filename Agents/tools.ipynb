# %% [markdown]
# ## 1. What are tools?
#
# -> A tool is just a Python function (or API) that is packaged in a way the LLM can understand and call when needed.
#
# | LLM's like Chatgpt are great at | They can't do things like |
# |------|---------------------------|
# |Reasoning| Access Live data          |
# |Language Generation | Do Reliable Math          |
# | | Call API's                |
# |  | Run Code|
# |   | Interact with database|
#
# ### LLM's uses the provided tools to perform some function.

# %% [markdown]
# Types of Tools:
#
#                         |Tools|
#                            |
#                            |
#                     ------------------
#                    |                |
#                Built in Tools    Custom Tools

# %% [markdown]
# ## How Tools fits into the Agent ecosystem?
# An Al agent is an LLM-powered system that can autonomously think, decide, and take actions using external tools or APIs to achieve a goal.
#
# |    Agent|                      |
# |-------|----------------------|
# |Reasoning and Decision Making (LLM's)| Action (using Tools) |
#
# Which implies Agents are LLM's  + Tools.

# %% [markdown]
# ## Built-in Tools
#
# A built-in tool is a tool that LangChain already provides for you —it's pre-built, production-ready, and requires minimal or no setup.
#
# You don't have to write the function logic yourself — you just import and use it.
#
# |Function Name | Does what? |
# |--------|--------|
# | DuckDuckGoSearchRun| Web search via DuckDuckGo|
# | WikipediaQueryRun | Wikipedia summary|
# | PythonREPLTool| Run raw Python code|
# | ShellTool | Run shell commands|
# | RequestsGetTool| Make HTTP GET requests|
# | GmailSendMessageTool | Send emails via Gmail|
# |SlackSendMessageTool| Post message to Slack|
# |SQLDatabaseQueryTool| Run SQL queries|

# %%
# !pip install langchain langchain-core langchain-community pydantic duckduckgo-search
# Out:
# Requirement already satisfied: langchain in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (0.3.25)
# Requirement already satisfied: langchain-core in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (0.3.60)
# Requirement already satisfied: langchain-community in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (0.3.24)
# Requirement already satisfied: pydantic in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (2.11.4)
# Requirement already satisfied: duckduckgo-search in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (8.0.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain) (0.3.42)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-core) (4.13.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from pydantic) (0.4.0)
# Requirement already satisfied: click>=8.1.8 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from duckduckgo-search) (8.1.8)
# Requirement already satisfied: primp>=0.15.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from duckduckgo-search) (5.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2025.4.26)
# Requirement already satisfied: anyio in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Built in tools - DuckDuckGo

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool= DuckDuckGoSearchRun()
results=search_tool.invoke('ipl playoffs')
print(results)
# Out:
# The Indian Premier League (IPL) 2025 Playoffs will begin from Thursday (May 29) at the Maharaja Yadavindra Singh International Cricket Stadium in Mullanpur with Punjab Kings facing off against Royal Challengers Bengaluru in Qualifier 1. The following day, on May 30, Mumbai Indians will lock horns ... The Board of Control for Cricket in India (BCCI) announced the schedule for the TATA Indian Premier League (IPL) 2025 Playoffs on Tuesday. After 70 action-packed league-stage matches filled with energy, drama, thrill, and entertainment; the spotlight will shift to the New PCA Stadium in New Chandigarh as it gears up to host the much-awaited ... The IPL 2025 playoffs follow a well-established format designed to give the top two teams from the league stage an advantage while keeping the competition open for the other qualifiers. The playoffs consist of four matches: Qualifier 1, Eliminator, Qualifier 2, and the Final. The IPL 2025 playoffs are approaching and all four teams have already secured their playoff spots. Only a few games are remaining as we reach the business end of the competition. Three-time runner ... The Gujarat Titans were the first to confirm their place in the IPL playoffs 2025. Led by the composed Shubman Gill, the Titans dominated the league stages, finishing with 18 points. Gill (601 ...

# %% [markdown]
# ## Built in tools - Shell Tools

# %%
! pip install langchain-experimental
# Out:
# Requirement already satisfied: langchain-experimental in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-experimental) (0.3.24)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.28 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-experimental) (0.3.60)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (4.13.2)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (2.11.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langchain<1.0.0,>=0.3.25->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.8)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2025.4.26)
# Requirement already satisfied: anyio in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_community.tools  import ShellTool
shell_tool = ShellTool()
results=shell_tool.invoke('whoami')
print(results)
# Out:
# Executing command:
#  whoami
# sushantniraula
# /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %%
from langchain_community.tools  import ShellTool
shell_tool = ShellTool()
results=shell_tool.invoke('ls')
print(results)
# Out:
# Executing command:
#  ls
# tools.ipynb
# /Users/sushantniraula/Coding/Gen AI/.venv/lib/python3.9/site-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
